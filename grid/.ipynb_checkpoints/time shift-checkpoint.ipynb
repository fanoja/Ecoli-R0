# %% [markdown]
# # Time shift between SIR and BSI
#
# - Uniform filter, convolution with the SIR result

# %%
import os
import importlib
os.getcwd()
os.chdir('/u/50/ojalaf2/unix/Dropbox (Aalto)/Ecoli/')

# %%
# !cp grid/grid_params/final_yearly_bsi/grid_params_A_I0.py grid/grid_params.py

# %%
# !python3 grid/run_grid.py
# Out:
# /u/50/ojalaf2/unix/Dropbox (Aalto)/Ecoli
# /u/50/ojalaf2/unix/Dropbox (Aalto)/Ecoli
# Current working directory: /u/50/ojalaf2/unix/Dropbox (Aalto)/Ecoli
# Using real data. Dataset: NORM, clade: A
# Iter: 0
# Iter: 1000
# Iter: 2000
# Iter: 3000
# Iter: 4000
# Iter: 5000
# Iter: 6000
# Iter: 7000
# Iter: 8000
# Iter: 9000
# Iter: 10000
# Iter: 11000
# Iter: 12000
# Iter: 13000
# Iter: 14000
# Iter: 15000
# Iter: 16000
# Iter: 17000
# Iter: 18000
# Iter: 19000
# Iter: 20000
# Iter: 21000
# Iter: 22000
# Iter: 23000
# Iter: 24000
# Iter: 25000
# Iter: 26000
# Iter: 27000
# Iter: 28000
# Iter: 29000
# Iter: 30000
# Iter: 31000
# Iter: 32000
# Iter: 33000
# Iter: 34000
# Iter: 35000
# Iter: 36000
# Iter: 37000
# Iter: 38000
# Iter: 39000
# Iter: 40000
# Iter: 41000
# Iter: 42000
# Iter: 43000
# Iter: 44000
# Iter: 45000
# Iter: 46000
# Iter: 47000
# Iter: 48000
# Iter: 49000
# Iter: 50000
# Iter: 51000
# Iter: 52000
# Iter: 53000
# Iter: 54000
# Iter: 55000
# Iter: 56000
# Iter: 57000
# ...

# %%
output_directory = "res/sim_res/obs_NORM_A_I0_2023-09-14_09-59-11"

dists = np.load(os.path.join(output_directory, "dists.npy"))
pairs = np.load(os.path.join(output_directory, "pairs.npy"))

# %%
import grid_functions
importlib.reload(grid_functions)
from grid_functions import *

# Fixed OR for plotting only the posterior uncertainty:
visualize_results("res/sim_res/obs_NORM_A_I0_2023-09-14_14-32-07_or_mu", 0.3)
# Out:
# Results to visualize: res/sim_res/obs_NORM_A_I0_2023-09-14_14-32-07_or_mu/sim_params.txt
# Year
# 2004    3.895481e-06
# 2005    3.949891e-10
# 2006    1.263574e-05
# 2007    4.214390e-06
# 2008    1.053623e-05
# 2009    5.791327e-06
# 2010    1.535184e-05
# 2011    8.640565e-06
# 2012    2.363202e-05
# 2013    3.185117e-05
# 2014    3.004447e-05
# 2015    1.012509e-05
# 2016    2.025119e-05
# 2017    2.130096e-05
# Name: A, dtype: float64
# Beta mean: 0.02639037086428042
# Gamma mean: 0.01728878012048193
# R = mean(beta/gamma): 1.5430707132697457
# R = median(beta/gamma): 1.543865140562249

# %%
import cluster.scripts.BSI_functions
importlib.reload(cluster.scripts.BSI_functions)
from cluster.scripts.BSI_functions import *

pairs = np.load("res/sim_res/BSI_i_and_BSI_max_t/obs_NORM_A_I0_2023-09-14_14-15-50/pairs.npy")
dists = np.load("res/sim_res/BSI_i_and_BSI_max_t/obs_NORM_A_I0_2023-09-14_14-15-50/dists.npy")
eps = 0.3

acc_pairs = pairs[np.where(dists < eps)[0], :]


par1_post_mean = np.mean(acc_pairs[:,0])
par2_post_mean = np.mean(acc_pairs[:,1])

print(par1_post_mean, par2_post_mean)


# Visualize uncertainty only associated with the odds ratio:

from cluster.scripts.load_data import *
from grid_params import *

bsi_pars = {"or_data": or_data, "clade": clade, "dataset": obs_data, "theta_c":theta_c, "theta_bsi":theta_bsi, "include_I0":True} # assume load_data loads or_data, norm_data and bsac_data

or_data.head()
clade = "A"
dataset = "NORM"

df = or_data[or_data["Label"] == f'{clade} ({dataset})']
or_mu = df["OR"].values

or_lower = df["lower"].values
or_upper = df["upper"].values

# deterministic with fixed or_hat values:
mu_sim = SIR_and_BSI_simulator(par1_post_mean, par2_post_mean, nt = 728, N = 1000000, bsi_pars = bsi_pars,\
                      is_prop = True, is_agg = True, time_period = 52, reparam = False,\
                      has_or_hat = True, manual_or_hat = or_mu, batch_size = 1, random_state = None)

median_sim = SIR_and_BSI_simulator(np.median(acc_pairs[:,0]), np.median(acc_pairs[:,1]), nt = 728, N = 1000000, bsi_pars = bsi_pars,\
                      is_prop = True, is_agg = True, time_period = 52, reparam = False,\
                      has_or_hat = True, manual_or_hat = or_mu, batch_size = 1, random_state = None)

lower_sim = SIR_and_BSI_simulator(par1_post_mean, par2_post_mean, nt = 728, N = 1000000, bsi_pars = bsi_pars,\
                      is_prop = True, is_agg = True, time_period = 52, reparam = False,\
                      has_or_hat = True, manual_or_hat = or_lower, batch_size = 1, random_state = None)

upper_sim = SIR_and_BSI_simulator(par1_post_mean, par2_post_mean, nt = 728, N = 1000000, bsi_pars = bsi_pars,\
                      is_prop = True, is_agg = True, time_period = 52, reparam = False,\
                      has_or_hat = True, manual_or_hat = or_upper, batch_size = 1, random_state = None)

print(lower_sim)
print(mu_sim)
print(upper_sim)



plt.title("OR uncertainty: OR is fixed")
plt.plot(lower_sim[0], color = "lightblue", linestyle='--', label = "OR CIs")
plt.plot(upper_sim[0], color = "lightblue", linestyle='--')
plt.plot(mu_sim[0], color = "blue", label = "mean")
plt.plot(median_sim[0], color = "pink", label = "median")


# Include also the posterior uncertainty 
ci = 90
par1_posterior = acc_pairs[:,0]
par2_posterior = acc_pairs[:,1]
par1_bounds = get_bounds(par1_posterior, ci)
par2_bounds = get_bounds(par2_posterior, ci)

post_lb = SIR_and_BSI_simulator(par1_bounds[0], par2_bounds[0], nt = 728, N = 1000000, bsi_pars = bsi_pars,\
                      is_prop = True, is_agg = True, time_period = 52, reparam = False,\
                      has_or_hat = True, manual_or_hat = or_mu, batch_size = 1, random_state = None)

post_ub = SIR_and_BSI_simulator(par1_bounds[1], par2_bounds[1], nt = 728, N = 1000000, bsi_pars = bsi_pars,\
                      is_prop = True, is_agg = True, time_period = 52, reparam = False,\
                      has_or_hat = True, manual_or_hat = or_mu, batch_size = 1, random_state = None)

plt.plot(post_lb[0], color = "grey", linestyle='--')
plt.plot(post_ub[0], color = "grey", linestyle='--', label = "Posterior CIs (90%)")


plt.legend()
plt.show()
# Out:
# 0.026745476460760906 0.01730120481927711
# [[4.91898887e-06 5.44405512e-06 6.53564122e-06 8.13172976e-06
#   9.99684020e-06 1.17497625e-05 1.30141630e-05 1.35777752e-05
#   1.34365497e-05 1.27301221e-05 1.16502382e-05 1.03766297e-05
#   9.04872215e-06 7.76123240e-06]]
# [[4.94907750e-06 5.51323027e-06 6.76083708e-06 8.77482689e-06
#   1.14966847e-05 1.46274135e-05 1.76446086e-05 1.99860680e-05
#   2.12798617e-05 2.14482765e-05 2.06522196e-05 1.91672116e-05
#   1.72781741e-05 1.52222118e-05]]
# [[4.96663193e-06 5.55437206e-06 6.90179296e-06 9.21061587e-06
#   1.26292709e-05 1.71062113e-05 2.22448902e-05 2.73051166e-05
#   3.14346316e-05 3.40002982e-05 3.47834863e-05 3.39501005e-05
#   3.18888077e-05 2.90454764e-05]]

# %%
import grid_functions
importlib.reload(grid_functions)
from grid_functions import *

# BSI_1,...,BSI_14, BSI_max_t
visualize_results("res/sim_res/obs_NORM_A_I0_2023-09-14_11-17-19_BSI_i_BSI_max_t", 0.5)
# Out:
# Results to visualize: res/sim_res/obs_NORM_A_I0_2023-09-14_11-17-19_BSI_i_BSI_max_t/sim_params.txt
# Year
# 2004    3.895481e-06
# 2005    3.949891e-10
# 2006    1.263574e-05
# 2007    4.214390e-06
# 2008    1.053623e-05
# 2009    5.791327e-06
# 2010    1.535184e-05
# 2011    8.640565e-06
# 2012    2.363202e-05
# 2013    3.185117e-05
# 2014    3.004447e-05
# 2015    1.012509e-05
# 2016    2.025119e-05
# 2017    2.130096e-05
# Name: A, dtype: float64
# Beta mean: 0.026107622482162505
# Gamma mean: 0.017053525577720722
# R = mean(beta/gamma): 1.7682843389953253
# R = median(beta/gamma): 1.543865140562249

# %%
import grid_functions
importlib.reload(grid_functions)
from grid_functions import *

# BSI_1,...,BSI_14
visualize_results("res/sim_res/obs_NORM_A_I0_2023-09-14_09-59-11", 0.3)
# Out:
# Results to visualize: res/sim_res/obs_NORM_A_I0_2023-09-14_09-59-11/sim_params.txt
# Year
# 2004    3.895481e-06
# 2005    3.949891e-10
# 2006    1.263574e-05
# 2007    4.214390e-06
# 2008    1.053623e-05
# 2009    5.791327e-06
# 2010    1.535184e-05
# 2011    8.640565e-06
# 2012    2.363202e-05
# 2013    3.185117e-05
# 2014    3.004447e-05
# 2015    1.012509e-05
# 2016    2.025119e-05
# 2017    2.130096e-05
# Name: A, dtype: float64
# Beta mean: 0.02051391364531755
# Gamma mean: 0.012618473895582329
# R = mean(beta/gamma): 1.8319774386434626
# R = median(beta/gamma): 1.6201301606425704

# %%
import grid_functions
importlib.reload(grid_functions)
from grid_functions import *

# BSI_vector + BSI_max_t
visualize_results("res/sim_res/obs_NORM_A_I0_2023-09-13_14-16-48_BSI_vector_BSI_max_t", 0.3)
# Out:
# Results to visualize: res/sim_res/obs_NORM_A_I0_2023-09-13_14-16-48_BSI_vector_BSI_max_t/sim_params.txt
# Year
# 2004    3.895481e-06
# 2005    3.949891e-10
# 2006    1.263574e-05
# 2007    4.214390e-06
# 2008    1.053623e-05
# 2009    5.791327e-06
# 2010    1.535184e-05
# 2011    8.640565e-06
# 2012    2.363202e-05
# 2013    3.185117e-05
# 2014    3.004447e-05
# 2015    1.012509e-05
# 2016    2.025119e-05
# 2017    2.130096e-05
# Name: A, dtype: float64
# Beta mean: 0.024031277854402566
# Gamma mean: 0.015743183259353203
# R = mean(beta/gamma): 1.8788473818719857
# R = median(beta/gamma): 1.543865140562249

# %%
# Load functions and data
import importlib
import numpy as np
import matplotlib.pyplot as plt

from cluster.scripts.BSI_functions import *
from cluster.scripts.SIR_functions import *
from cluster.scripts.load_data import *

# %%
par1 = 0.145
par2 = 0.026
print(f"Beta: {par1}, gamma: {par2}")
print(f"R0: {par1/par2}")

nt = 16*52
N = 1000000

sir = SIR(par1, par2, nt, N, reparam = False, batch_size=1, random_state = None)
# Plot the result:
plt.plot(sir[1][0]) # 1 = I compartment, 0 = first batch
plt.title(f"SIR, I compartment (colonisation)\n N = {N}")
plt.show()
# Out:
# Beta: 0.145, gamma: 0.026
# R0: 5.576923076923077

# %%
# Apply a uniform filter with convolution:

# Simulated bsi:
clade = "A"
obs_data = "NORM"
n_weeks = 14*52
pop_size = 1000000
is_prop = True
is_agg = True

# These are the mean values for beta and gamma when fitting the model to observed data:
true_par1 = 0.0740571043023658
true_par2 = 0.046887883517877184

bsi_pars = {"or_data": or_data, "clade": clade, "dataset": obs_data, "theta_c":1, "theta_bsi":0.00002/52, "include_I0": False}
bsi_sim = SIR_and_BSI_simulator(true_par1, true_par2, nt = n_weeks, N = pop_size,\
                                bsi_pars = bsi_pars, is_prop = True,\
                                is_agg = True, time_period = 52, batch_size = 1, random_state = None)
bsi_obs = get_incidence_data("data/NORM_incidence.csv", clade = clade, is_prop = is_prop, n_incidence_pop = pop_size)
print(np.array(bsi_obs))
print(bsi_sim)
plt.plot(bsi_sim[0])
#plt.plot(np.array(bsi_obs))
plt.show()
# Out:
# [3.89548110e-06 3.94989077e-10 1.26357430e-05 4.21438992e-06
#  1.05362331e-05 5.79132651e-06 1.53518358e-05 8.64056533e-06
#  2.36320218e-05 3.18511701e-05 3.00444681e-05 1.01250923e-05
#  2.02511905e-05 2.13009564e-05]
# [[2.32140498e-11 9.35654373e-11 3.77062148e-10 1.51858912e-09
#   6.10071914e-09 2.42648931e-08 9.28186686e-08 3.08927293e-07
#   7.00664380e-07 8.29434506e-07 5.29380539e-07 2.37441681e-07
#   9.19773635e-08 3.37505631e-08]]

# %%
0.00002/52
# Out:
# 3.8461538461538463e-07

# %%
l = 30


# Convolution
x = bsi_sim[0]
alpha = 0.2 # if alpha = 1, then we get an identical sequence. If alpha is decreased, the peak moves forwards and is lowered too.
bsi_filtered = np.zeros(len(x))
bsi_filtered[0] = bsi_sim[0][0] # initialize at the first value of the sequence
print(bsi_filtered)
for i in range(1, len(x)):
    bsi_filtered[i] = alpha*x[i] + (1-alpha)*bsi_filtered[i-1] # This is exponential smoothing. Is this what we want?
    
#bsi_filtered = np.convolve(exp_filter, bsi_sim[0])
print(bsi_filtered)
plt.plot(bsi_filtered, label = "Filtered BSI")
plt.plot(x, label = "Original BSI")
plt.legend()
plt.show()
# Out:
# [2.32140498e-11 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# [2.32140498e-11 3.72843273e-11 1.05239891e-10 3.87909737e-10
#  1.53047162e-09 6.07735592e-09 2.34256184e-08 8.05259533e-08
#  2.04553639e-07 3.29529812e-07 3.69499957e-07 3.43088302e-07
#  2.92866114e-07 2.41043004e-07]

# %%
print(bsi_sim.shape)
len(bsi_sim)
# Out:
# (1, 14)
# 1

# %%
bsi_sim
# Out:
# array([[2.32140498e-11, 9.35654373e-11, 3.77062148e-10, 1.51858912e-09,
#         6.10071914e-09, 2.42648931e-08, 9.28186686e-08, 3.08927293e-07,
#         7.00664380e-07, 8.29434506e-07, 5.29380539e-07, 2.37441681e-07,
#         9.19773635e-08, 3.37505631e-08]])

# %%
def exp_col_model(I, t, alpha):
    # This function can be used instead of SIR model for colonization.
    
    
    
    pass

# %% [markdown]
# ## Understanding convolution

# %%
x = np.linspace(0, 10, 100)
l = 3

plt.plot(x)
plt.title("x")
plt.show()

def exp_pdf(l, x):
    return l*np.exp(-l*x)

# Filter
plt.plot(exp_pdf(l, x))
plt.title(f"Exp PDF, l = {l}")
plt.show()


# Flipped filter
plt.plot(exp_pdf(l, -x))
plt.title(f"Exp PDF, l = {l}")
plt.show()

filtered = np.zeros(len(bsi_sim[0]))
exp_filter = exp_pdf(l, x)

for i in range(0, len(filtered)):
    for j in range(0, len(exp_filter)):
        filtered[i] += bsi_sim[0][i]*exp_filter[i - j + len(bsi_sim[0])] # this just smooths the distribution.
    filtered[i] /= len(exp_filter)

plt.plot(filtered)
plt.plot(bsi_sim[0])
#plt.plot(np.convolve(bsi_sim[0], exp_filter))
plt.show()


# ???

# %%
def list_convolve(arr1, arr2):
    # TODO: implement convolution of two lists of arbitrary length
    
    conv = np.zeros(len(arr1) + len(arr2) - 1)
    
    for k in range(0, len(conv)):
        pass 


list_convolve([1,2,3], [4,5,6])
# Out:
# 1
# 2
# 3
