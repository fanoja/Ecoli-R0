# %% [markdown]
# # Grid Visualization
#
# This notebook is dedicated to the visualizations, no testing etc here.

# %%
import os
os.getcwd()

os.chdir('/u/50/ojalaf2/unix/Dropbox (Aalto)/Ecoli/')

import importlib
import numpy as np
import matplotlib.pyplot as plt

import grid_functions
importlib.reload(grid_functions)
from grid_functions import *


from cluster.scripts.BSI_functions import *

import cluster.scripts.BSI_functions
importlib.reload(cluster.scripts.BSI_functions)
from cluster.scripts.BSI_functions import *

import cluster.scripts.SIR_functions
importlib.reload(cluster.scripts.SIR_functions)
from cluster.scripts.SIR_functions import *

incidence = True # If true, use incidence data instead of proportions.

print(os.getcwd())

from cluster.scripts.load_data import *
# Out:
# Loading BSI_functions.py
# Current working directory: /u/50/ojalaf2/unix/Dropbox (Aalto)/Ecoli
# Loading BSI_functions.py
# Loading BSI_functions.py
# Loading BSI_functions.py
# /u/50/ojalaf2/unix/Dropbox (Aalto)/Ecoli

# %% [markdown]
# This cell does the visualisation. Simply change the file path to visualize results of a specific model.

# %%
# For changes in any of the files below to take effect, please reload the modules by running this cell.
import grid_functions
importlib.reload(grid_functions)
from grid_functions import *

import cluster.scripts.BSI_functions
importlib.reload(cluster.scripts.BSI_functions)
from cluster.scripts.BSI_functions import *

import cluster.scripts.SIR_functions
importlib.reload(cluster.scripts.SIR_functions)
from cluster.scripts.SIR_functions import *

visualize_results("res/sim_res/alpha/A_alpha_6_2023-11-20_16-10-57", 0.2)
# Out:
# Loading BSI_functions.py
# Loading BSI_functions.py
# Results to visualize: res/sim_res/alpha/A_alpha_6_2023-11-20_16-10-57/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.7', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/A_alpha_6_2023-11-20_16-10-57', 'clade': 'A', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     3.895481
# 2005     0.000395
# 2006    12.635743
# 2007     4.214390
# 2008    10.536233
# 2009     5.791327
# 2010    15.351836
# 2011     8.640565
# 2012    23.632022
# 2013    31.851170
# 2014    30.044468
# 2015    10.125092
# 2016    20.251191
# 2017    21.300956
# Name: A, dtype: float64
# Beta or nt mean: 0.06227110659281455
# Gamma or R mean: 0.03289750565165345
# ...

# %% [markdown]
# # Visualizing the (beta, gamma) parametrisation

# %% [markdown]
# # Visualizing the reparametrized (net transmission, R) model

# %% [markdown]
# # Visualizing different values of alpha

# %% [markdown]
# ## Clade A

# %%
# These should only differ by the value of alpha and stochasticity associated with the simulation. 
# Therefore, we use a fixed value for the distance:

a_eps = 0.2

# %%
visualize_results("res/sim_res/alpha/A_alpha_1_2023-11-20_14-59-20", a_eps) # alpha = 0.2
# Out:
# Results to visualize: res/sim_res/alpha/A_alpha_1_2023-11-20_14-59-20/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.2', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/A_alpha_1_2023-11-20_14-59-20', 'clade': 'A', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     3.895481
# 2005     0.000395
# 2006    12.635743
# 2007     4.214390
# 2008    10.536233
# 2009     5.791327
# 2010    15.351836
# 2011     8.640565
# 2012    23.632022
# 2013    31.851170
# 2014    30.044468
# 2015    10.125092
# 2016    20.251191
# 2017    21.300956
# Name: A, dtype: float64
# Beta or nt mean: 0.055753949532213465
# Gamma or R mean: 0.020405255360123734
# R = mean(beta/gamma): 2.9472899813440865
# ...

# %%
visualize_results("res/sim_res/alpha/A_alpha_3_2023-11-20_15-28-15", a_eps) # alpha = 0.4
# Out:
# Results to visualize: res/sim_res/alpha/A_alpha_3_2023-11-20_15-28-15/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.4', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/A_alpha_3_2023-11-20_15-28-15', 'clade': 'A', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     3.895481
# 2005     0.000395
# 2006    12.635743
# 2007     4.214390
# 2008    10.536233
# 2009     5.791327
# 2010    15.351836
# 2011     8.640565
# 2012    23.632022
# 2013    31.851170
# 2014    30.044468
# 2015    10.125092
# 2016    20.251191
# 2017    21.300956
# Name: A, dtype: float64
# Beta or nt mean: 0.05841103005849977
# Gamma or R mean: 0.026743217973481472
# R = mean(beta/gamma): 2.4626215983447244
# ...

# %%
visualize_results("res/sim_res/alpha/A_alpha_5_2023-11-20_15-56-48", a_eps) # alpha = 0.5
# Out:
# Results to visualize: res/sim_res/alpha/A_alpha_5_2023-11-20_15-56-48/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.6', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/A_alpha_5_2023-11-20_15-56-48', 'clade': 'A', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     3.895481
# 2005     0.000395
# 2006    12.635743
# 2007     4.214390
# 2008    10.536233
# 2009     5.791327
# 2010    15.351836
# 2011     8.640565
# 2012    23.632022
# 2013    31.851170
# 2014    30.044468
# 2015    10.125092
# 2016    20.251191
# 2017    21.300956
# Name: A, dtype: float64
# Beta or nt mean: 0.06225738912177441
# Gamma or R mean: 0.03261317635035272
# R = mean(beta/gamma): 2.1371236657619286
# ...

# %%
visualize_results("res/sim_res/alpha/A_alpha_6_2023-11-20_16-10-57", a_eps) # alpha = 0.6
# Out:
# Results to visualize: res/sim_res/alpha/A_alpha_6_2023-11-20_16-10-57/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.7', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/A_alpha_6_2023-11-20_16-10-57', 'clade': 'A', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     3.895481
# 2005     0.000395
# 2006    12.635743
# 2007     4.214390
# 2008    10.536233
# 2009     5.791327
# 2010    15.351836
# 2011     8.640565
# 2012    23.632022
# 2013    31.851170
# 2014    30.044468
# 2015    10.125092
# 2016    20.251191
# 2017    21.300956
# Name: A, dtype: float64
# Beta or nt mean: 0.06227110659281455
# Gamma or R mean: 0.03289750565165345
# R = mean(beta/gamma): 2.125622006403081
# ...

# %%
visualize_results("res/sim_res/alpha/A_alpha_7_2023-11-20_16-25-24", a_eps) # alpha = 0.8
# Out:
# Results to visualize: res/sim_res/alpha/A_alpha_7_2023-11-20_16-25-24/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.8', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/A_alpha_7_2023-11-20_16-25-24', 'clade': 'A', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     3.895481
# 2005     0.000395
# 2006    12.635743
# 2007     4.214390
# 2008    10.536233
# 2009     5.791327
# 2010    15.351836
# 2011     8.640565
# 2012    23.632022
# 2013    31.851170
# 2014    30.044468
# 2015    10.125092
# 2016    20.251191
# 2017    21.300956
# Name: A, dtype: float64
# Beta or nt mean: 0.05998241821962672
# Gamma or R mean: 0.03065039468734371
# R = mean(beta/gamma): 2.2466089784517655
# ...

# %%
visualize_results("res/sim_res/alpha/A_alpha_8_2023-11-20_16-39-49", a_eps) # alpha = 0.9
# Out:
# Results to visualize: res/sim_res/alpha/A_alpha_8_2023-11-20_16-39-49/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.9', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/A_alpha_8_2023-11-20_16-39-49', 'clade': 'A', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     3.895481
# 2005     0.000395
# 2006    12.635743
# 2007     4.214390
# 2008    10.536233
# 2009     5.791327
# 2010    15.351836
# 2011     8.640565
# 2012    23.632022
# 2013    31.851170
# 2014    30.044468
# 2015    10.125092
# 2016    20.251191
# 2017    21.300956
# Name: A, dtype: float64
# Beta or nt mean: 0.062489192202392865
# Gamma or R mean: 0.034063714861346614
# R = mean(beta/gamma): 2.114908555943842
# ...

# %% [markdown]
# ## Clade C2

# %%
# Use the same distance threshold for all values of alpha:
c2_eps = 0.12

# %%
visualize_results("res/sim_res/alpha/C2_alpha_0_2023-11-20_14-45-21", c2_eps) # alpha = 0.1
# Out:
# Results to visualize: res/sim_res/alpha/C2_alpha_0_2023-11-20_14-45-21/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.1', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/C2_alpha_0_2023-11-20_14-45-21', 'clade': 'C2', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     0.000390
# 2005     0.000395
# 2006     0.000421
# 2007     8.428780
# 2008     7.024155
# 2009     8.686990
# 2010     3.070367
# 2011     5.760377
# 2012    10.741828
# 2013    21.234113
# 2014    13.656576
# 2015    25.312731
# 2016    15.188393
# 2017    16.567411
# Name: C2, dtype: float64
# Beta or nt mean: 0.097273672565687
# Gamma or R mean: 0.07204610901427196
# R = mean(beta/gamma): 1.5802981976679114
# ...

# %%
visualize_results("res/sim_res/alpha/C2_alpha_1_2023-11-20_15-13-42", c2_eps) # alpha = 0.2
# Out:
# Results to visualize: res/sim_res/alpha/C2_alpha_1_2023-11-20_15-13-42/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.2', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/C2_alpha_1_2023-11-20_15-13-42', 'clade': 'C2', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     0.000390
# 2005     0.000395
# 2006     0.000421
# 2007     8.428780
# 2008     7.024155
# 2009     8.686990
# 2010     3.070367
# 2011     5.760377
# 2012    10.741828
# 2013    21.234113
# 2014    13.656576
# 2015    25.312731
# 2016    15.188393
# 2017    16.567411
# Name: C2, dtype: float64
# Beta or nt mean: 0.12143093623394047
# Gamma or R mean: 0.09935174706773717
# R = mean(beta/gamma): 1.330001147942253
# ...

# %%
visualize_results("res/sim_res/alpha/C2_alpha_3_2023-11-20_15-30-44", c2_eps) # alpha = 0.4
# Out:
# Results to visualize: res/sim_res/alpha/C2_alpha_3_2023-11-20_15-30-44/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.4', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/C2_alpha_3_2023-11-20_15-30-44', 'clade': 'C2', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     0.000390
# 2005     0.000395
# 2006     0.000421
# 2007     8.428780
# 2008     7.024155
# 2009     8.686990
# 2010     3.070367
# 2011     5.760377
# 2012    10.741828
# 2013    21.234113
# 2014    13.656576
# 2015    25.312731
# 2016    15.188393
# 2017    16.567411
# Name: C2, dtype: float64
# Beta or nt mean: 0.1280476988010656
# Gamma or R mean: 0.10776902464351805
# R = mean(beta/gamma): 1.2832686019490842
# ...

# %%
visualize_results("res/sim_res/alpha/C2_alpha_4_2023-11-20_15-46-11", c2_eps) # alpha = 0.5
# Out:
# Results to visualize: res/sim_res/alpha/C2_alpha_4_2023-11-20_15-46-11/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.5', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/C2_alpha_4_2023-11-20_15-46-11', 'clade': 'C2', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     0.000390
# 2005     0.000395
# 2006     0.000421
# 2007     8.428780
# 2008     7.024155
# 2009     8.686990
# 2010     3.070367
# 2011     5.760377
# 2012    10.741828
# 2013    21.234113
# 2014    13.656576
# 2015    25.312731
# 2016    15.188393
# 2017    16.567411
# Name: C2, dtype: float64
# Beta or nt mean: 0.1282516770530898
# Gamma or R mean: 0.10834995912264826
# R = mean(beta/gamma): 1.2702682194575274
# ...

# %%
visualize_results("res/sim_res/alpha/C2_alpha_5_2023-11-20_16-01-53", c2_eps) # alpha = 0.6
# Out:
# Results to visualize: res/sim_res/alpha/C2_alpha_5_2023-11-20_16-01-53/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.6', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/C2_alpha_5_2023-11-20_16-01-53', 'clade': 'C2', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     0.000390
# 2005     0.000395
# 2006     0.000421
# 2007     8.428780
# 2008     7.024155
# 2009     8.686990
# 2010     3.070367
# 2011     5.760377
# 2012    10.741828
# 2013    21.234113
# 2014    13.656576
# 2015    25.312731
# 2016    15.188393
# 2017    16.567411
# Name: C2, dtype: float64
# Beta or nt mean: 0.14094516513123448
# Gamma or R mean: 0.12212011990320538
# R = mean(beta/gamma): 1.2083058894154275
# ...

# %%
visualize_results("res/sim_res/alpha/C2_alpha_6_2023-11-20_16-17-08", c2_eps) # alpha = 0.7
# Out:
# Results to visualize: res/sim_res/alpha/C2_alpha_6_2023-11-20_16-17-08/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.7', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/C2_alpha_6_2023-11-20_16-17-08', 'clade': 'C2', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     0.000390
# 2005     0.000395
# 2006     0.000421
# 2007     8.428780
# 2008     7.024155
# 2009     8.686990
# 2010     3.070367
# 2011     5.760377
# 2012    10.741828
# 2013    21.234113
# 2014    13.656576
# 2015    25.312731
# 2016    15.188393
# 2017    16.567411
# Name: C2, dtype: float64
# Beta or nt mean: 0.1255501995546147
# Gamma or R mean: 0.10633341260054668
# R = mean(beta/gamma): 1.2923335090489585
# ...

# %%
visualize_results("res/sim_res/alpha/C2_alpha_7_2023-11-20_16-32-18", c2_eps) # alpha = 0.8
# Out:
# Results to visualize: res/sim_res/alpha/C2_alpha_7_2023-11-20_16-32-18/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.8', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/C2_alpha_7_2023-11-20_16-32-18', 'clade': 'C2', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     0.000390
# 2005     0.000395
# 2006     0.000421
# 2007     8.428780
# 2008     7.024155
# 2009     8.686990
# 2010     3.070367
# 2011     5.760377
# 2012    10.741828
# 2013    21.234113
# 2014    13.656576
# 2015    25.312731
# 2016    15.188393
# 2017    16.567411
# Name: C2, dtype: float64
# Beta or nt mean: 0.13366665299286265
# Gamma or R mean: 0.11497316043918832
# R = mean(beta/gamma): 1.2667599090016315
# ...

# %%
visualize_results("res/sim_res/alpha/C2_alpha_8_2023-11-20_16-47-34", c2_eps) # alpha = 0.9
# Out:
# Results to visualize: res/sim_res/alpha/C2_alpha_8_2023-11-20_16-47-34/sim_params.txt
# {'n_weeks': 728, 'pop_size': 1000000, 'is_prop': False, 'is_agg': True, 'time_period': 52, 'reparam': False, 'alpha': '0.9', 'batch_size': 1, 'random_state': None, 'n_grid': 35000, 'output_directory': 'res/sim_res/C2_alpha_8_2023-11-20_16-47-34', 'clade': 'C2', 'dataset': 'NORM', 'theta_c': 1.0, 'theta_bsi': 1.2769982306628324e-05, 'include_I0': False}
# KeyError: Synthetic data not available, using observed data
# bsi_obs_data in visualize_results
# Year
# 2004     0.000390
# 2005     0.000395
# 2006     0.000421
# 2007     8.428780
# 2008     7.024155
# 2009     8.686990
# 2010     3.070367
# 2011     5.760377
# 2012    10.741828
# 2013    21.234113
# 2014    13.656576
# 2015    25.312731
# 2016    15.188393
# 2017    16.567411
# Name: C2, dtype: float64
# Beta or nt mean: 0.14295375950024194
# Gamma or R mean: 0.12470613689342776
# R = mean(beta/gamma): 1.2688243572605429
# ...
